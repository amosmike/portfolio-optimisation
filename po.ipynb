# %%
# https://www.youtube.com/watch?v=xagKMaTjxjk
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from datetime import datetime
current_date = datetime.today().strftime('%Y-%m-%d')
from pandas_datareader import data as pdr
from datetime import date
import yfinance as yf
import datetime
yf.pdr_override()

# %%
assets = ['AMD', 'NFLX', 'AAPL', 'GOOG']
weights = np.array([0.25, 0.25, 0.25, 0.25])

# %%
startdate = '2015-01-01'

# %%
today = date.today().strftime('%Y-%m-%d')

# %%
df = pd.DataFrame()

for stock in assets:
    df[stock] = pdr.get_data_yahoo(stock, start=startdate, end=today)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                   AMD        NFLX        AAPL        GOOG
# Date
# 2015-01-02   2.670000   49.848572   24.565697   26.168653
# 2015-01-05   2.660000   47.311428   23.873640   25.623152
# 2015-01-06   2.630000   46.501431   23.875885   25.029282
# 2015-01-07   2.580000   46.742859   24.210676   24.986401
# 2015-01-08   2.610000   47.779999   25.140913   25.065184
# ...               ...         ...         ...         ...
# 2023-02-08  84.690002  366.829987  151.688400  100.000000
# 2023-02-09  83.209999  362.500000  150.639999   95.459999
# 2023-02-10  81.480003  347.359985  151.009995   94.860001
# 2023-02-13  83.129997  358.570007  153.850006   95.000000
# 2023-02-14  85.949997  359.959991  153.199997   94.949997
#
# [2044 rows x 4 columns]

# %%
title = 'Portfolio Adj. Close Price History'

my_stocks = df
for c in my_stocks.columns.values:
    plt.plot(my_stocks[c], label=c)

plt.title(title)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Adj. Price USD ($)', fontsize=18)
plt.legend(my_stocks.columns.values, loc='upper left')
plt.show()
